# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"/content/ex.csv")
df
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                         Singer/Artists  \
# 0                  Kumar Sanu, Mika Singh, Neha Kakkar
# 1                             Neha Kakkar, Tony Kakkar
# 2                                        Ranveer Singh
# 3                Jyotica Tangri, Shaan, Subhro Ganguly
# 4     Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
# ...                                                ...
# 2415                                            Mukesh
# ...

# %%
df.isnull().sum()
# Out:
# Song-Name          0
# Singer/Artists    10
# Genre              0
# Album/Movie        3
# User-Rating        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Song-Name         0
# Singer/Artists    0
# Genre             0
# Album/Movie       0
# User-Rating       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(16)

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (2391, 5)

# %%
df.head()
# Out:
#           Song-Name                                    Singer/Artists  \
# 0       Aankh Marey               Kumar Sanu, Mika Singh, Neha Kakkar
# 1         Coca Cola                          Neha Kakkar, Tony Kakkar
# 2  Apna Time Aayega                                     Ranveer Singh
# 3            Mungda             Jyotica Tangri, Shaan, Subhro Ganguly
# 4          Tere Bin  Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
#
#                     Genre    Album/Movie User-Rating
# 0          BollywoodDance         Simmba      8.8/10
# 1  BollywoodDanceRomantic    Luka Chuppi      9.0/10
# 2          BollywoodDance      Gully Boy      9.7/10
# 3          BollywoodDance  Total Dhamaal      9.1/10
# 4       BollywoodRomantic         Simmba      9.2/10

# %%
df['User-Rating']
# Out:
# 0       8.8/10
# 1       9.0/10
# 2       9.7/10
# 3       9.1/10
# 4       9.2/10
#          ...
# 2415    6.2/10
# 2416    7.2/10
# 2417    7.5/10
# 2418    6.5/10
# 2419    6.6/10
# Name: User-Rating, Length: 2391, dtype: object

# %%
l=[]
for i in df['User-Rating']:
    l.append(i[1:3])
l
# Out:
# ['.8',
#  '.0',
#  '.7',
#  '.1',
#  '.2',
#  '.1',
#  '.2',
#  '.5',
#  '.2',
#  '.6',
#  '.8',
#  '.4',
#  '.1',
#  '.2',
#  '.0',
#  '.7',
#  '.1',
#  '.0',
#  '.0',
#  '.1',
#  '.2',
#  '.2',
#  '.5',
#  '.6',
#  '.1',
#  '.0',
#  '.0',
#  '.2',
#  '.5',
#  '.4',
#  '.7',
#  '.3',
#  '.3',
#  '.5',
#  '.1',
#  '.0',
#  '.0',
#  '.1',
#  '.4',
#  '.4',
#  '.8',
#  '.2',
#  '.2',
#  '.6',
#  '.6',
#  '.0',
#  '.1',
#  '.5',
#  '.5',
#  '.5',
#  '.7',
#  '.9',
#  '.6',
#  '.5',
#  '.1',
#  '.7',
#  '.6',
#  '.3',
#  '.7',
#  '.9',
#  '.0',
#  '.0',
#  '.3',
#  '.3',
#  '.1',
#  '.0',
#  '.7',
#  '.2',
#  '.1',
#  '.0',
#  '.9',
#  '.5',
#  '.5',
#  '.7',
#  '.0',
#  '.1',
#  '.1',
#  '.5',
#  '.1',
#  '.6',
#  '.4',
#  '.0',
#  '.0',
#  '.6',
#  '.3',
#  '.0',
#  '.2',
#  '.3',
#  '.1',
#  '.6',
#  '.5',
#  '.5',
#  '.0',
#  '.4',
#  '.2',
#  '.6',
#  '.3',
#  '.7',
#  '.2',
#  '.3',
#  '.7',
#  '.0',
#  '.5',
#  '.4',
#  '.0',
#  '.2',
#  '.0',
#  '.4',
#  '.4',
#  '.1',
#  '.3',
# ...

# %%
df['User-Rating']=l
df
# Out:
# <ipython-input-13-38b136296adc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['User-Rating']=l
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                         Singer/Artists  \
# 0                  Kumar Sanu, Mika Singh, Neha Kakkar
# ...

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y="Genre", data=df, order=df['Genre'].value_counts().index, palette="viridis")
plt.title("Genre Distribution", fontsize=16)
plt.xlabel("Count")
plt.ylabel("Genre")
plt.show()
# Out:
# <ipython-input-14-76336048f42a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y="Genre", data=df, order=df['Genre'].value_counts().index, palette="viridis")

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['User-Rating'], kde=True, bins=20, color="blue")
plt.title("User-Rating Distribution", fontsize=16)
plt.xlabel("User Rating")
plt.ylabel("Frequency")
plt.show()

# %%
top_artists = df['Singer/Artists'].value_counts().head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_artists.values, y=top_artists.index, palette="mako")
plt.title("Top 10 Singers/Artists by Song Count", fontsize=16)
plt.xlabel("Count")
plt.ylabel("Singer/Artist")
plt.show()
# Out:
# <ipython-input-16-19e55c279c09>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_artists.values, y=top_artists.index, palette="mako")

# %%
top_albums = df['Album/Movie'].value_counts().head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_albums.values, y=top_albums.index, palette="coolwarm")
plt.title("Top 10 Albums/Movies by Song Count", fontsize=16)
plt.xlabel("Count")
plt.ylabel("Album/Movie")
plt.show()
# Out:
# <ipython-input-17-1351f501e719>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_albums.values, y=top_albums.index, palette="coolwarm")

# %%
plt.figure(figsize=(8, 6))
if len(df.select_dtypes(include=["float64", "int64"]).columns) > 1:
    correlation_matrix = df.corr()
    sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", cbar=True, fmt=".2f")
    plt.title("Correlation Heatmap", fontsize=16)
else:
    print("Not enough numerical columns for a meaningful correlation heatmap.")
plt.show()
# Out:
# Not enough numerical columns for a meaningful correlation heatmap.

# %%
df['Album/Movie']=df['Album/Movie'].str.replace(' ','')
df['Singer/Artists']=df['Singer/Artists'].str.replace(' ','')
df
# Out:
# <ipython-input-19-371c8b49fd25>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Album/Movie']=df['Album/Movie'].str.replace(' ','')
# <ipython-input-19-371c8b49fd25>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Singer/Artists']=df['Singer/Artists'].str.replace(' ','')
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# ...

# %%
df['Singer/Artists']=df['Singer/Artists'].str.replace(',',' ')
df
# Out:
# <ipython-input-20-7733f995defa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Singer/Artists']=df['Singer/Artists'].str.replace(',',' ')
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                  Singer/Artists                   Genre  \
# ...

# %%
df['tags']=df['Singer/Artists']+' '+df['Genre']+' '+df['Album/Movie']+' '+df['User-Rating']
df
# Out:
# <ipython-input-21-a1a285c3c870>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags']=df['Singer/Artists']+' '+df['Genre']+' '+df['Album/Movie']+' '+df['User-Rating']
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
# ...

# %%
df['tags']=df['Singer/Artists']+' '+df['Genre']+' '+df['Album/Movie']+' '+df['User-Rating']
df['tags'][0]
# Out:
# <ipython-input-22-d88c39f053ce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags']=df['Singer/Artists']+' '+df['Genre']+' '+df['Album/Movie']+' '+df['User-Rating']
# 'KumarSanu MikaSingh NehaKakkar BollywoodDance Simmba .8'

# %%
new_df=df[['Song-Name','tags']]
new_df
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                                    tags
# 0     KumarSanu MikaSingh NehaKakkar BollywoodDance ...
# 1     NehaKakkar TonyKakkar BollywoodDanceRomantic L...
# 2               RanveerSingh BollywoodDance GullyBoy .7
# 3     JyoticaTangri Shaan SubhroGanguly BollywoodDan...
# 4     AseesKaur RahatFatehAliKhan TanishkBagchi Boll...
# ...                                                 ...
# 2415                   Mukesh BollywoodDance Sasural .2
# ...

# %%
new_df['tags']=new_df['tags'].apply(lambda x:x.lower())
new_df
# Out:
# <ipython-input-24-b71b42d80788>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']=new_df['tags'].apply(lambda x:x.lower())
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                                    tags
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=2000)

# %%
vectors=cv.fit_transform(new_df['tags']).toarray()

# %%
vectors.shape
# Out:
# (2391, 1697)

# %%
cv.get_feature_names_out()
# Out:
# array(['13', '1920', '1921', ..., 'zindaginamilegidobara',
#        'zindagiyehzindagi', 'zubeengarg'], dtype=object)

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity=cosine_similarity(vectors)

# %%
sorted(list(enumerate(similarity[0])),reverse=True,key=lambda x:x[1])
# Out:
# [(0, np.float64(0.9999999999999999)),
#  (5, np.float64(0.5163977794943223)),
#  (34, np.float64(0.5163977794943223)),
#  (184, np.float64(0.5163977794943223)),
#  (269, np.float64(0.5163977794943223)),
#  (371, np.float64(0.5163977794943223)),
#  (465, np.float64(0.5163977794943223)),
#  (540, np.float64(0.5163977794943223)),
#  (587, np.float64(0.5163977794943223)),
#  (606, np.float64(0.5163977794943223)),
#  (820, np.float64(0.5163977794943223)),
#  (919, np.float64(0.5163977794943223)),
#  (1388, np.float64(0.5163977794943223)),
#  (1600, np.float64(0.5163977794943223)),
#  (1931, np.float64(0.5163977794943223)),
#  (2145, np.float64(0.5163977794943223)),
#  (2272, np.float64(0.5163977794943223)),
#  (2358, np.float64(0.5163977794943223)),
#  (11, np.float64(0.4472135954999579)),
#  (35, np.float64(0.4472135954999579)),
#  (40, np.float64(0.4472135954999579)),
#  (88, np.float64(0.4472135954999579)),
#  (115, np.float64(0.4472135954999579)),
# ...

# %%
new_df.rename(columns={'Song-Name':'title'},inplace=True)
# Out:
# <ipython-input-31-9a52c662c89c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.rename(columns={'Song-Name':'title'},inplace=True)

# %%
def recommend(music):
    music_index=new_df[new_df['title']==music].index[0]
    distances=similarity[music_index]
    music_list=sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:6]
    for i in music_list:
        print(new_df.iloc[i[0]].title)

# %%
recommend('Proper Patola')
# Out:
# Abhi Toh Party Shuru Hui Hai
# Bhare Bazaar
# Tareefan Remix
# Pant Mein Gun
# Pee Paa Pee Paa

# %%
df.head(50)
# Out:
#                           Song-Name  \
# 0                       Aankh Marey
# 1                         Coca Cola
# 2                  Apna Time Aayega
# 3                            Mungda
# 4                          Tere Bin
# 5                         Gali Gali
# 6                     Chamma Chamma
# 7                   Mere Gully Mein
# 8                          Kamariya
# 9   Ek Ladki Ko Dekha Toh Aisa Laga
# 10                   Swag Se Swagat
# 11                  Poster Lagwa Do
# 12                      Daaru Wargi
# 13                           Dilbar
# 14                    Proper Patola
# 15                            Doori
# 16                 Dil Diyan Gallan
# 17                     Husn Parcham
# 18                  Bom Diggy Diggy
# 19                       Issaqbaazi
# 20                     Mere Naam Tu
# 21    High Rated Gabru – Nawabzaade
# 22                    Dekhte Dekhte
# 23                          Zingaat
# 24                         Tareefan
# ...

# %%
import pickle
pickle.dump(new_df,open('musicrec.pkl','wb'))

# %%
pickle.dump(similarity,open('similarities.pkl','wb'))
